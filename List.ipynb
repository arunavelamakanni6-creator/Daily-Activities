# %% [markdown]
# ## LIST

# %%
l=[]
print(l)
print(type(l))
# Out:
# []
# <class 'list'>

# %%
l=[1,2,3,4,5,6]
print(l)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
l.append(7)
print(l)
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %%
l.insert(1,8)
print(l)
# Out:
# [1, 8, 2, 3, 4, 5, 6, 7]

# %%
l.pop()
print(l)
# Out:
# [1, 8, 2, 3, 4, 5, 6]

# %%
l.pop(1)
print(l)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
l.remove(5)
print(l)
# Out:
# [1, 2, 3, 4, 6]

# %%
l1=[1,2,3]
l2=[4,5,6]
l1.append(l2)
print(l1)
# Out:
# [1, 2, 3, [4, 5, 6]]

# %%
l1=[1,2,3]
l2=[4,5,6]
l1.extend(l2)
print(l1)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
print(l)
# Out:
# [1, 2, 3, 4, 6]

# %%
l.clear()
print(l)
# Out:
# []

# %%
del l

# %%
print(l)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 print(l)
#
# NameError: name 'l' is not defined

# %%
l=[1,5,6,8,2,8,9]
l.sort()
print(l)
# Out:
# [1, 2, 5, 6, 8, 8, 9]

# %%
l=[1,5,6,8,2,8,9]
print(sorted(l))
# Out:
# [1, 2, 5, 6, 8, 8, 9]

# %%
l=[1,5,6,8,2,8,9]
l.reverse()
print(l)
# Out:
# [9, 8, 2, 8, 6, 5, 1]
